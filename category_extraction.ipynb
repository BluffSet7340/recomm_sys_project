# %% [markdown]
# Use another dataset and merge it with the dataset used for calculating the Wilson Score so that we can get the tags needed for content based collaborative filtering

# %%
import pandas as pd 
import numpy as np

# %%
# load the dataframe used for wilson scoring
df_wilson = pd.read_json('game_stats_wilson.json', orient='records', lines=True)

# %%
df_wilson.head()
# Out:
#     appid            game  total_votes  upvotes  downvotes  wilson_score
# 0     550   Left 4 Dead 2         1309     1309          0      0.997074
# 1  644560          Mirror          925      925          0      0.995864
# 2  264710      Subnautica         1333     1332          1      0.995763
# 3  294100        RimWorld         1294     1293          1      0.995635
# 4  413150  Stardew Valley         2240     2236          4      0.995417

# %%
df_wilson.shape
# Out:
# (27315, 6)

# %%
# just need the appid and game
df_wilson_games = df_wilson[['appid', 'game']]

# %%
df_wilson_games.head()
# Out:
#     appid            game
# 0     550   Left 4 Dead 2
# 1  644560          Mirror
# 2  264710      Subnautica
# 3  294100        RimWorld
# 4  413150  Stardew Valley

# %%
# load dataframe that has game tags
df_tags = pd.read_json('obsolete/steam_games_preprocessed.json')

# %%
df_tags
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty
# 1                     Ironbound                 Ironbound
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                       弹炸人2222                   弹炸人2222
# 4                 Log Challenge                       NaN
# ...                         ...                       ...
# 32130            Colony On Mars            Colony On Mars
# 32131  LOGistICAL: South Africa  LOGistICAL: South Africa
# 32132             Russian Roads             Russian Roads
# 32133       EXIT 2 - Directions       EXIT 2 - Directions
# 32134               Maze Run VR                       NaN
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/773570/Log_C...          NaN
# ...                                                  ...          ...
# 32130  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 32131  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 32132  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 32133  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 32134  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4                        [Action, Indie, Casual, Sports]            1.79
# ...                                                  ...             ...
# 32130              [Strategy, Indie, Casual, Simulation]            1.49
# 32131                          [Strategy, Indie, Casual]            4.24
# 32132                        [Indie, Simulation, Racing]            1.39
# 32133  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/773570/reviews/?...
# ...                                                  ...
# 32130  http://steamcommunity.com/app/773640/reviews/?...
# 32131  http://steamcommunity.com/app/733530/reviews/?...
# 32132  http://steamcommunity.com/app/610660/reviews/?...
# 32133  http://steamcommunity.com/app/658870/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access        id                 developer        sentiment  \
# 0             False  761140.0                 Kotoshiro              NaN
# 1             False  643980.0          Secret Level SRL  Mostly Positive
# 2             False  670290.0              Poolians.com  Mostly Positive
# 3             False  767400.0                      彼岸领域              NaN
# 4             False  773570.0                       NaN              NaN
# ...             ...       ...                       ...              ...
# 32130         False  773640.0        Nikita "Ghost_RUS"              NaN
# 32131         False  733530.0                    Sacada              NaN
# 32132         False  610660.0  Laush Dmitriy Sergeevich              NaN
# 32133         False  658870.0             xropi,stev3ns   1 user reviews
# 32134          True  681550.0                       NaN         Positive
#
#       metascore
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 32130       NaN
# 32131       NaN
# 32132       NaN
# 32133       NaN
# 32134       NaN
#
# [32135 rows x 16 columns]

# %% [markdown]
# publisher, genres, tags, and specs all seem to be useful for content based collaborative filtering, let's take all of them

# %%
# take the columns I want
df_tags_important = df_tags[['id', 'app_name', 'genres', 'tags', 'publisher']]

# %%
df_tags_important.head()
# Out:
#          id                 app_name  \
# 0  761140.0      Lost Summoner Kitty
# 1  643980.0                Ironbound
# 2  670290.0  Real Pool 3D - Poolians
# 3  767400.0                  弹炸人2222
# 4  773570.0            Log Challenge
#
#                                               genres  \
# 0      [Action, Casual, Indie, Simulation, Strategy]
# 1               [Free to Play, Indie, RPG, Strategy]
# 2  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                        [Action, Adventure, Casual]
# 4                                                NaN
#
#                                                 tags         publisher
# 0      [Strategy, Action, Indie, Casual, Simulation]         Kotoshiro
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...  Making Fun, Inc.
# 2  [Free to Play, Simulation, Sports, Casual, Ind...      Poolians.com
# 3                        [Action, Adventure, Casual]              彼岸领域
# 4                    [Action, Indie, Casual, Sports]               NaN

# %%
df_tags_important.shape
# Out:
# (32135, 5)

# %% [markdown]
# Merge both datasets but only keep the games that belong to df_wilson

# %%
# Ensure game names are case-insensitive and merge datasets
df_wilson['game_lower'] = df_wilson['game'].str.lower()
df_tags_important['app_name_lower'] = df_tags_important['app_name'].str.lower()

# Merge datasets on the lowercased game name
merged_df = pd.merge(
    df_wilson,
    df_tags_important,
    left_on='game_lower',
    right_on='app_name_lower',
    how='left'
)

# Drop unnecessary columns after merging
merged_df = merged_df.drop(columns=['game_lower', 'app_name_lower'])
# Out:
# C:\Users\sbm76\AppData\Local\Temp\ipykernel_17136\136158262.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tags_important['app_name_lower'] = df_tags_important['app_name'].str.lower()

# %%
# Display the first few rows of the merged DataFrame
merged_df.head(100)
# Out:
#       appid                  game  total_votes  upvotes  downvotes  \
# 0       550         Left 4 Dead 2         1309     1309          0
# 1    644560                Mirror          925      925          0
# 2    264710            Subnautica         1333     1332          1
# 3    294100              RimWorld         1294     1293          1
# 4    413150        Stardew Valley         2240     2236          4
# ..      ...                   ...          ...      ...        ...
# 95      220           Half-Life 2          406      404          2
# 96   224260  No More Room in Hell          209      209          0
# 97  1657630       Slime Rancher 2          209      209          0
# 98   383870             Firewatch          207      207          0
# 99   282140                  SOMA          207      207          0
#
#     wilson_score        id              app_name  \
# 0       0.997074     550.0         Left 4 Dead 2
# 1       0.995864       NaN                   NaN
# 2       0.995763  264710.0            Subnautica
# 3       0.995635  294100.0              RimWorld
# 4       0.995417  413150.0        Stardew Valley
# ..           ...       ...                   ...
# 95      0.982219     220.0           Half-Life 2
# 96      0.981951  224260.0  No More Room in Hell
# 97      0.981951       NaN                   NaN
# 98      0.981780  383870.0             Firewatch
# 99      0.981780  282140.0                  SOMA
#
#                                          genres  \
# 0                                      [Action]
# 1                                           NaN
# 2                                           NaN
# 3   [Indie, Simulation, Strategy, Early Access]
# 4                      [Indie, RPG, Simulation]
# ..                                          ...
# 95                                     [Action]
# 96                [Action, Free to Play, Indie]
# 97                                          NaN
# 98                           [Adventure, Indie]
# 99                   [Action, Adventure, Indie]
#
#                                                  tags                publisher
# 0   [Zombies, Co-op, FPS, Multiplayer, Action, Onl...                    Valve
# 1                                                 NaN                      NaN
# 2   [Early Access, Survival, Open World, Explorati...                      NaN
# 3   [Early Access, Base Building, Survival, Strate...           Ludeon Studios
# 4   [RPG, Simulation, Pixel Graphics, Agriculture,...              Chucklefish
# ..                                                ...                      ...
# 95  [FPS, Action, Sci-fi, Singleplayer, Classic, S...                    Valve
# 96  [Free to Play, Zombies, Multiplayer, Survival,...              Lever Games
# 97                                                NaN                      NaN
# 98  [Atmospheric, Adventure, Walking Simulator, St...  Panic Inc., Campo Santo
# 99  [Horror, Atmospheric, Story Rich, Sci-fi, Psyc...         Frictional Games
#
# [100 rows x 11 columns]

# %%
merged_df.shape
# Out:
# (27354, 11)

# %%
# Drop entries with missing genres
merged_df_valid_genres = merged_df.dropna(subset=['genres'])

# %%
merged_df_valid_genres.shape
# Out:
# (7434, 11)

# %% [markdown]
# Let's remove all the games that don't have genres since we can't use them for content based collaborative filtering

# %%
merged_df_valid_genres.head()
# Out:
#     appid                    game  total_votes  upvotes  downvotes  \
# 0     550           Left 4 Dead 2         1309     1309          0
# 3  294100                RimWorld         1294     1293          1
# 4  413150          Stardew Valley         2240     2236          4
# 6   48700  Mount & Blade: Warband          689      689          0
# 7      10          Counter-Strike          611      611          0
#
#    wilson_score        id                app_name  \
# 0      0.997074     550.0           Left 4 Dead 2
# 3      0.995635  294100.0                RimWorld
# 4      0.995417  413150.0          Stardew Valley
# 6      0.994455   48700.0  Mount & Blade: Warband
# 7      0.993752      10.0          Counter-Strike
#
#                                         genres  \
# 0                                     [Action]
# 3  [Indie, Simulation, Strategy, Early Access]
# 4                     [Indie, RPG, Simulation]
# 6                                [Action, RPG]
# 7                                     [Action]
#
#                                                 tags                 publisher
# 0  [Zombies, Co-op, FPS, Multiplayer, Action, Onl...                     Valve
# 3  [Early Access, Base Building, Survival, Strate...            Ludeon Studios
# 4  [RPG, Simulation, Pixel Graphics, Agriculture,...               Chucklefish
# 6  [Medieval, RPG, Open World, Strategy, Action, ...  TaleWorlds Entertainment
# 7  [Action, FPS, Multiplayer, Shooter, Classic, T...                     Valve

# %%
# columns that I need
merged_df_valid_genres = merged_df_valid_genres[['appid', 'game', 'genres', 'tags', 'publisher']]

# %%
merged_df_valid_genres.head()
# Out:
#     appid                    game  \
# 0     550           Left 4 Dead 2
# 3  294100                RimWorld
# 4  413150          Stardew Valley
# 6   48700  Mount & Blade: Warband
# 7      10          Counter-Strike
#
#                                         genres  \
# 0                                     [Action]
# 3  [Indie, Simulation, Strategy, Early Access]
# 4                     [Indie, RPG, Simulation]
# 6                                [Action, RPG]
# 7                                     [Action]
#
#                                                 tags                 publisher
# 0  [Zombies, Co-op, FPS, Multiplayer, Action, Onl...                     Valve
# 3  [Early Access, Base Building, Survival, Strate...            Ludeon Studios
# 4  [RPG, Simulation, Pixel Graphics, Agriculture,...               Chucklefish
# 6  [Medieval, RPG, Open World, Strategy, Action, ...  TaleWorlds Entertainment
# 7  [Action, FPS, Multiplayer, Shooter, Classic, T...                     Valve

# %% [markdown]
# Save this file as json

# %%
merged_df_valid_genres.to_json('merged_df_valid_genres.json', orient='records', lines=True)
